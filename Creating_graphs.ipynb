# %%
import numpy as np
import torch 
import pandas as pd
import torch_geometric.transforms as T
import os 
import json
from NetworkAnalysis import Create_heterogeneous_graph

# %% [markdown]
# # For pan-cancer dataset

# %%
files = os.listdir('./config/experiments')
files = [file for file in files if 'C4' not in file and 'gnn_gnn' in file]
print(files)
# Out:
# ['gnn_gnn_expression_marker_genes_cgp.json', 'gnn_gnn_expression_hvg_cgp.json', 'gnn_gnn_cnv_cgp.json', 'gnn_gnn_MOSA_cgp.json']

# %%
for file in files:
    # Load configuration from the JSON file
    path = './config/experiments/' + file
    with open(path, 'r') as config_file:
        config = json.load(config_file)

    # Extract parameters with new structure
    graph_params = config["graph_parameters"]

    graph_creator = Create_heterogeneous_graph(
        BASE_PATH=graph_params["base_path"],
        cancer_type=graph_params["cancer_type"],
        cell_feature=graph_params["cell_feat_name"],
        gene_feature=graph_params["gene_feat_name"],
        metapaths=graph_params["metapaths"]
    )
    heterodata_obj = graph_creator.run_pipeline()
# Out:
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 1160 cells, feature type: expression_marker_genes
# Warning: 70 cells are missing features:
# ['ACH-000047', 'ACH-000246', 'ACH-000426', 'ACH-001039', 'ACH-001065'] ...
# Applied StandardScaler normalization to cell features (mean=[1.54251523 6.21231691 0.90165888 0.59538907 0.79820183]..., var=[1.42580704 3.77323214 2.47712332 1.44162096 1.68399769]...)
# Final network will have 13398 genes and 1090 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 53728 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# /Users/jovanafilipovic/Downloads/MSc Bioinformatics/Year 2/Thesis/GIT_HetGNN/env/lib/python3.11/site-packages/torch_geometric/edge_index.py:2007: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:55.)
#   out = torch.matmul(sparse_input, other)
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_All_cgp_expression_marker_genes_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 1160 cells, feature type: expression_hvg
# Warning: 70 cells are missing features:
# ['ACH-000047', 'ACH-000246', 'ACH-000426', 'ACH-001039', 'ACH-001065'] ...
# Applied StandardScaler normalization to cell features (mean=[6.03427455 2.20304538 5.76257489 6.0985331  0.6996399 ]..., var=[ 7.41294633  4.26842229 13.83660647 13.40056616  3.73837251]...)
# Final network will have 13398 genes and 1090 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 53728 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_All_cgp_expression_hvg_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 1160 cells, feature type: cnv
# Warning: 2 cells are missing features:
# ['ACH-001227', 'ACH-002475']
# Applied StandardScaler normalization to cell features (mean=[1.01248332 1.01248332 1.01248332 1.01248332 1.01223066]..., var=[0.5156739  0.5156739  0.5156739  0.5156739  0.51629645]...)
# Final network will have 13398 genes and 1158 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 55944 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_All_cgp_cnv_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 1160 cells, feature type: MOSA
# Warning: 481 cells are missing features:
# ['ACH-000011', 'ACH-000025', 'ACH-000026', 'ACH-000029', 'ACH-000036'] ...
# Using MOSA embeddings without normalization
# Final network will have 13398 genes and 679 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 36771 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_All_cgp_MOSA_META2.pt

# %% [markdown]
# # For Neuroblastoma

# %%
files = os.listdir('./config/experiments')
files = [file for file in files if 'gnn_gnn' in file]
print(files)
# Out:
# ['gnn_gnn_expression_marker_genes_cgp.json', 'gnn_gnn_expression_marker_genes_C4.json', 'gnn_gnn_cnv_C4.json', 'gnn_gnn_expression_hvg_cgp.json', 'gnn_gnn_cnv_cgp.json', 'gnn_gnn_MOSA_cgp.json', 'gnn_gnn_expression_hvg_C4.json', 'gnn_gnn_MOSA_C4.json']

# %%
for file in files:
    # Load configuration from the JSON file
    path = './config/experiments/' + file
    with open(path, 'r') as config_file:
        config = json.load(config_file)

    # Extract parameters with new structure
    graph_params = config["graph_parameters"]

    graph_creator = Create_heterogeneous_graph(
        BASE_PATH=graph_params["base_path"],
        cancer_type="Neuroblastoma",
        cell_feature=graph_params["cell_feat_name"],
        gene_feature=graph_params["gene_feat_name"],
        metapaths=graph_params["metapaths"]
    )
    heterodata_obj = graph_creator.run_pipeline()
# Out:
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: expression_marker_genes
# Warning: 7 cells are missing features:
# ['ACH-002083', 'ACH-002261', 'ACH-002278', 'ACH-002280', 'ACH-002282'] ...
# Applied StandardScaler normalization to cell features (mean=[1.9776399  6.99115479 0.37844806 0.11597532 0.15120327]..., var=[0.35065828 0.38319137 0.38251511 0.02051516 0.05406979]...)
# Final network will have 13398 genes and 32 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 588 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_cgp_expression_marker_genes_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 5341 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: expression_marker_genes
# Warning: 7 cells are missing features:
# ['ACH-002083', 'ACH-002261', 'ACH-002278', 'ACH-002280', 'ACH-002282'] ...
# Applied StandardScaler normalization to cell features (mean=[1.9776399  6.99115479 0.37844806 0.11597532 0.15120327]..., var=[0.35065828 0.38319137 0.38251511 0.02051516 0.05406979]...)
# Final network will have 8693 genes and 32 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 405 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_C4_expression_marker_genes_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 5341 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: cnv
# Applied StandardScaler normalization to cell features (mean=[0.91257963 0.86070499 1.03059266 1.03059266 1.03059266]..., var=[0.33515745 0.192242   0.74188562 0.74188562 0.74188562]...)
# Final network will have 8693 genes and 39 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 500 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_C4_cnv_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: expression_hvg
# Warning: 7 cells are missing features:
# ['ACH-002083', 'ACH-002261', 'ACH-002278', 'ACH-002280', 'ACH-002282'] ...
# Applied StandardScaler normalization to cell features (mean=[1.74038142 6.83822333 2.94688606 2.63717405 5.61549945]..., var=[2.81930902 3.11169922 2.40010214 9.20442501 7.52854599]...)
# Final network will have 13398 genes and 32 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 588 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_cgp_expression_hvg_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: cnv
# Applied StandardScaler normalization to cell features (mean=[0.91257963 0.86070499 1.03059266 1.03059266 1.03059266]..., var=[0.33515745 0.192242   0.74188562 0.74188562 0.74188562]...)
# Final network will have 13398 genes and 39 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 735 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_cgp_cnv_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: MOSA
# Warning: 13 cells are missing features:
# ['ACH-000203', 'ACH-000446', 'ACH-001300', 'ACH-001301', 'ACH-001302'] ...
# Using MOSA embeddings without normalization
# Final network will have 13398 genes and 26 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 510 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_cgp_MOSA_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 5341 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: expression_hvg
# Warning: 7 cells are missing features:
# ['ACH-002083', 'ACH-002261', 'ACH-002278', 'ACH-002280', 'ACH-002282'] ...
# Applied StandardScaler normalization to cell features (mean=[1.74038142 6.83822333 2.94688606 2.63717405 5.61549945]..., var=[2.81930902 3.11169922 2.40010214 9.20442501 7.52854599]...)
# Final network will have 8693 genes and 32 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 405 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_C4_expression_hvg_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 5341 out of 14034 genes have no features
# Processing cell features...
# Processing features for 39 cells, feature type: MOSA
# Warning: 13 cells are missing features:
# ['ACH-000203', 'ACH-000446', 'ACH-001300', 'ACH-001301', 'ACH-001302'] ...
# Using MOSA embeddings without normalization
# Final network will have 8693 genes and 26 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 352 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Neuroblastoma_C4_MOSA_META2.pt

# %% [markdown]
# # For lung-cancer

# %%
files = os.listdir('./config/experiments')
files = [file for file in files if 'C4' not in file and 'gnn_gnn' in file]
print(files)
# Out:
# ['gnn_gnn_expression_marker_genes_cgp.json', 'gnn_gnn_expression_hvg_cgp.json', 'gnn_gnn_cnv_cgp.json', 'gnn_gnn_MOSA_cgp.json']

# %%
for file in files:
    # Load configuration from the JSON file
    path = './config/experiments/' + file
    with open(path, 'r') as config_file:
        config = json.load(config_file)

    # Extract parameters with new structure
    graph_params = config["graph_parameters"]

    graph_creator = Create_heterogeneous_graph(
        BASE_PATH=graph_params["base_path"],
        cancer_type="Non-Small Cell Lung Cancer",
        cell_feature=graph_params["cell_feat_name"],
        gene_feature=graph_params["gene_feat_name"],
        metapaths=graph_params["metapaths"]
    )
    heterodata_obj = graph_creator.run_pipeline()
# Out:
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 98 cells, feature type: expression_marker_genes
# Warning: 3 cells are missing features:
# ['ACH-001137', 'ACH-001233', 'ACH-002156']
# Applied StandardScaler normalization to cell features (mean=[1.08233429 6.74757681 0.83438839 0.57644046 0.67755345]..., var=[0.3696076  0.60742336 1.51528629 1.0750473  0.62718758]...)
# Final network will have 13398 genes and 95 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 4976 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_expression_marker_genes_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 98 cells, feature type: expression_hvg
# Warning: 3 cells are missing features:
# ['ACH-001137', 'ACH-001233', 'ACH-002156']
# Applied StandardScaler normalization to cell features (mean=[6.57524674 2.99888512 7.28055145 1.0548815  5.96522707]..., var=[ 6.14176219  4.35276604  8.706919    5.78109097 10.09925337]...)
# Final network will have 13398 genes and 95 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 4976 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_expression_hvg_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 98 cells, feature type: cnv
# Applied StandardScaler normalization to cell features (mean=[1.27151583 1.81276682 1.81276682 1.81276682 1.05180898]..., var=[0.35155648 1.89641252 1.89641252 1.89641252 0.42328664]...)
# Final network will have 13398 genes and 98 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 5159 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_cnv_META2.pt
# Loading data...
# Continuing with Gene1 and Gene2 as columns for the nodes
# 14034 Nodes and 278974 interactions
# Filtering data for network membership...
# Filtering for informative genes...
# Creating dependency network using informative genes...
# Processing gene features...
# Warning: 636 out of 14034 genes have no features
# Processing cell features...
# Processing features for 98 cells, feature type: MOSA
# Warning: 24 cells are missing features:
# ['ACH-000029', 'ACH-000143', 'ACH-000251', 'ACH-000339', 'ACH-000390'] ...
# Using MOSA embeddings without normalization
# Final network will have 13398 genes and 74 cell lines
# Creating mutation network...
# Loading mutation data from ./Data/Depmap/OmicsSomaticMutationsMatrixDamaging.csv (damaging) and ./Data/Depmap/OmicsSomaticMutationsMatrixHotspot.csv (hotspot)
# Created mutation network with 3793 edges from damaging and hotspot data.
# Adding metapaths to the graph...
# Adding the following metapaths: [[('cell', 'has_mutation_in', 'gene'), ('gene', 'rev_has_mutation_in', 'cell')]]
# HeteroData saved to ./Data/multigraphs/heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_MOSA_META2.pt

# %% [markdown]
# # Load graphs

# %%
graphs = os.listdir('./Data/multigraphs/')
for graph in graphs:
    path = './Data/multigraphs/' + graph
    het_graph = torch.load(path)
    print(graph)
    print(het_graph)
# Out:
# heteroData_gene_cell_Neuroblastoma_cgp_expression_marker_genes_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[32],
#     names=[32],
#     x=[32, 3000],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 29438],
#     edge_label=[29438],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 588],
#     edge_attr=[588],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 29438],
#     edge_label=[29438],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 588],
#     edge_attr=[588],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 238],
#     edge_weight=[238],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_cgp_expression_hvg_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[32],
#     names=[32],
#     x=[32, 957],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 29438],
#     edge_label=[29438],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 588],
#     edge_attr=[588],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 29438],
#     edge_label=[29438],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 588],
#     edge_attr=[588],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 238],
#     edge_weight=[238],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_C4_cnv_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[8693],
#     names=[8693],
#     x=[8693, 1006],
#   },
#   cell={
#     node_id=[39],
#     names=[39],
#     x=[39, 1224],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 158466] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 25260],
#     edge_label=[25260],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 500],
#     edge_attr=[500],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 158466] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 25260],
#     edge_label=[25260],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 500],
#     edge_attr=[500],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 291],
#     edge_weight=[291],
#   }
# )
# heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_expression_hvg_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[95],
#     names=[95],
#     x=[95, 957],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 72592],
#     edge_label=[72592],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 4976],
#     edge_attr=[4976],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 72592],
#     edge_label=[72592],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 4976],
#     edge_attr=[4976],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 7429],
#     edge_weight=[7429],
#   }
# )
# heteroData_gene_cell_All_cgp_expression_hvg_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[1090],
#     names=[1090],
#     x=[1090, 957],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 966899],
#     edge_label=[966899],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 53728],
#     edge_attr=[53728],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 966899],
#     edge_label=[966899],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 53728],
#     edge_attr=[53728],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 674922],
#     edge_weight=[674922],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_C4_expression_marker_genes_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[8693],
#     names=[8693],
#     x=[8693, 1006],
#   },
#   cell={
#     node_id=[32],
#     names=[32],
#     x=[32, 3000],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 158466] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 20686],
#     edge_label=[20686],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 405],
#     edge_attr=[405],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 158466] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 20686],
#     edge_label=[20686],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 405],
#     edge_attr=[405],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 180],
#     edge_weight=[180],
#   }
# )
# heteroData_gene_cell_All_cgp_expression_marker_genes_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[1090],
#     names=[1090],
#     x=[1090, 3000],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 966899],
#     edge_label=[966899],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 53728],
#     edge_attr=[53728],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 966899],
#     edge_label=[966899],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 53728],
#     edge_attr=[53728],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 674922],
#     edge_weight=[674922],
#   }
# )
# heteroData_gene_cell_All_cgp_cnv_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[1158],
#     names=[1158],
#     x=[1158, 1218],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 1027815],
#     edge_label=[1027815],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 55944],
#     edge_attr=[55944],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 1027815],
#     edge_label=[1027815],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 55944],
#     edge_attr=[55944],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 765902],
#     edge_weight=[765902],
#   }
# )
# heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_expression_marker_genes_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[95],
#     names=[95],
#     x=[95, 3000],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 72592],
#     edge_label=[72592],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 4976],
#     edge_attr=[4976],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 72592],
#     edge_label=[72592],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 4976],
#     edge_attr=[4976],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 7429],
#     edge_weight=[7429],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_cgp_cnv_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[39],
#     names=[39],
#     x=[39, 1224],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 35849],
#     edge_label=[35849],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 735],
#     edge_attr=[735],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 35849],
#     edge_label=[35849],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 735],
#     edge_attr=[735],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 355],
#     edge_weight=[355],
#   }
# )
# heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_cnv_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[98],
#     names=[98],
#     x=[98, 1218],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 74873],
#     edge_label=[74873],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 5159],
#     edge_attr=[5159],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 74873],
#     edge_label=[74873],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 5159],
#     edge_attr=[5159],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 7950],
#     edge_weight=[7950],
#   }
# )
# heteroData_gene_cell_Non-Small_Cell_Lung_Cancer_cgp_MOSA_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[74],
#     names=[74],
#     x=[74, 215],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 55964],
#     edge_label=[55964],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 3793],
#     edge_attr=[3793],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 55964],
#     edge_label=[55964],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 3793],
#     edge_attr=[3793],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 4546],
#     edge_weight=[4546],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_cgp_MOSA_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[26],
#     names=[26],
#     x=[26, 215],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 23634],
#     edge_label=[23634],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 510],
#     edge_attr=[510],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 23634],
#     edge_label=[23634],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 510],
#     edge_attr=[510],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 154],
#     edge_weight=[154],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_C4_expression_hvg_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[8693],
#     names=[8693],
#     x=[8693, 1006],
#   },
#   cell={
#     node_id=[32],
#     names=[32],
#     x=[32, 957],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 158466] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 20686],
#     edge_label=[20686],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 405],
#     edge_attr=[405],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 158466] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 20686],
#     edge_label=[20686],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 405],
#     edge_attr=[405],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 180],
#     edge_weight=[180],
#   }
# )
# heteroData_gene_cell_Neuroblastoma_C4_MOSA_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[8693],
#     names=[8693],
#     x=[8693, 1006],
#   },
#   cell={
#     node_id=[26],
#     names=[26],
#     x=[26, 215],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 158466] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 16651],
#     edge_label=[16651],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 352],
#     edge_attr=[352],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 158466] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 16651],
#     edge_label=[16651],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 352],
#     edge_attr=[352],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 138],
#     edge_weight=[138],
#   }
# )
# heteroData_gene_cell_All_cgp_MOSA_META2.pt
# HeteroData(
#   metapath_dict={ (cell, metapath_0, cell)=[2] },
#   gene={
#     node_id=[13398],
#     names=[13398],
#     x=[13398, 3438],
#   },
#   cell={
#     node_id=[679],
#     names=[679],
#     x=[679, 215],
#   },
#   (gene, interacts_with, gene)={ edge_index=[2, 263122] },
#   (gene, dependency_of, cell)={
#     edge_index=[2, 600613],
#     edge_label=[600613],
#   },
#   (cell, has_mutation_in, gene)={
#     edge_index=[2, 36771],
#     edge_attr=[36771],
#   },
#   (gene, rev_interacts_with, gene)={ edge_index=[2, 263122] },
#   (cell, rev_dependency_of, gene)={
#     edge_index=[2, 600613],
#     edge_label=[600613],
#   },
#   (gene, rev_has_mutation_in, cell)={
#     edge_index=[2, 36771],
#     edge_attr=[36771],
#   },
#   (cell, metapath_0, cell)={
#     edge_index=[2, 296173],
#     edge_weight=[296173],
#   }
# )
