# %% [markdown]
# # ANALYSIS OF BENCHMARK

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data

# %%
data = [
    # GNN
    {"Model": "GNN", "Gene feature": "CGP", "Cell feature": "CNV", "Test AP": 0.90, "Test gene AP": 0.86, "Test cell AP": 0.87},
    {"Model": "GNN", "Gene feature": "CGP", "Cell feature": "MOSA", "Test AP": 0.93, "Test gene AP": 0.92, "Test cell AP": 0.91},
    {"Model": "GNN", "Gene feature": "CGP", "Cell feature": "expression", "Test AP": 0.91, "Test gene AP": 0.90, "Test cell AP": 0.89},
    {"Model": "GNN", "Gene feature": "CGP", "Cell feature": "expression_mg", "Test AP": 0.91, "Test gene AP": 0.90, "Test cell AP": 0.89},
    {"Model": "GNN", "Gene feature": "C4", "Cell feature": "CNV", "Test AP": 0.89, "Test gene AP": 0.86, "Test cell AP": 0.88},
    {"Model": "GNN", "Gene feature": "C4", "Cell feature": "MOSA", "Test AP": 0.89, "Test gene AP": 0.90, "Test cell AP": 0.86},
    {"Model": "GNN", "Gene feature": "C4", "Cell feature": "expression", "Test AP": 0.90, "Test gene AP": 0.89, "Test cell AP": 0.86},
    {"Model": "GNN", "Gene feature": "C4", "Cell feature": "expression_mg", "Test AP": 0.90, "Test gene AP": 0.90, "Test cell AP": 0.87},

    # GNN-GNN
    {"Model": "GNN-GNN", "Gene feature": "CGP", "Cell feature": "CNV", "Test AP": 0.92, "Test gene AP": 0.88, "Test cell AP": 0.89},
    {"Model": "GNN-GNN", "Gene feature": "CGP", "Cell feature": "MOSA", "Test AP": 0.90, "Test gene AP": 0.90, "Test cell AP": 0.88},
    {"Model": "GNN-GNN", "Gene feature": "CGP", "Cell feature": "expression", "Test AP": 0.91, "Test gene AP": 0.89, "Test cell AP": 0.89},
    {"Model": "GNN-GNN", "Gene feature": "CGP", "Cell feature": "expression_mg", "Test AP": 0.92, "Test gene AP": 0.90, "Test cell AP": 0.90},
    {"Model": "GNN-GNN", "Gene feature": "C4", "Cell feature": "CNV", "Test AP": 0.92, "Test gene AP": 0.88, "Test cell AP": 0.89},
    {"Model": "GNN-GNN", "Gene feature": "C4", "Cell feature": "MOSA", "Test AP": 0.91, "Test gene AP": 0.92, "Test cell AP": 0.89},
    {"Model": "GNN-GNN", "Gene feature": "C4", "Cell feature": "expression", "Test AP": 0.92, "Test gene AP": 0.90, "Test cell AP": 0.89},
    {"Model": "GNN-GNN", "Gene feature": "C4", "Cell feature": "expression_mg", "Test AP": 0.91, "Test gene AP": 0.91, "Test cell AP": 0.87},

    # MLP-GNN
    {"Model": "MLP-GNN", "Gene feature": "CGP", "Cell feature": "CNV", "Test AP": 0.93, "Test gene AP": 0.89, "Test cell AP": 0.90},
    {"Model": "MLP-GNN", "Gene feature": "CGP", "Cell feature": "MOSA", "Test AP": 0.92, "Test gene AP": 0.90, "Test cell AP": 0.90},
    {"Model": "MLP-GNN", "Gene feature": "CGP", "Cell feature": "expression", "Test AP": 0.93, "Test gene AP": 0.91, "Test cell AP": 0.91},
    {"Model": "MLP-GNN", "Gene feature": "CGP", "Cell feature": "expression_mg", "Test AP": 0.92, "Test gene AP": 0.90, "Test cell AP": 0.90},
    {"Model": "MLP-GNN", "Gene feature": "C4", "Cell feature": "CNV", "Test AP": 0.92, "Test gene AP": 0.87, "Test cell AP": 0.89},
    {"Model": "MLP-GNN", "Gene feature": "C4", "Cell feature": "MOSA", "Test AP": 0.92, "Test gene AP": 0.91, "Test cell AP": 0.91},
    {"Model": "MLP-GNN", "Gene feature": "C4", "Cell feature": "expression", "Test AP": 0.92, "Test gene AP": 0.90, "Test cell AP": 0.90},
    {"Model": "MLP-GNN", "Gene feature": "C4", "Cell feature": "expression_mg", "Test AP": 0.92, "Test gene AP": 0.91, "Test cell AP": 0.89},

    # MLP
    {"Model": "MLP", "Gene feature": "CGP", "Cell feature": "CNV", "Test AP": 0.93, "Test gene AP": 0.90, "Test cell AP": 0.91},
    {"Model": "MLP", "Gene feature": "CGP", "Cell feature": "MOSA", "Test AP": 0.93, "Test gene AP": 0.93, "Test cell AP": 0.90},
    {"Model": "MLP", "Gene feature": "CGP", "Cell feature": "expression", "Test AP": 0.92, "Test gene AP": 0.92, "Test cell AP": 0.89},
    {"Model": "MLP", "Gene feature": "CGP", "Cell feature": "expression_mg", "Test AP": 0.93, "Test gene AP": 0.92, "Test cell AP": 0.90},
    {"Model": "MLP", "Gene feature": "C4", "Cell feature": "CNV", "Test AP": 0.88, "Test gene AP": 0.88, "Test cell AP": 0.85},
    {"Model": "MLP", "Gene feature": "C4", "Cell feature": "MOSA", "Test AP": 0.90, "Test gene AP": 0.91, "Test cell AP": 0.87},
    {"Model": "MLP", "Gene feature": "C4", "Cell feature": "expression", "Test AP": 0.90, "Test gene AP": 0.92, "Test cell AP": 0.88},
    {"Model": "MLP", "Gene feature": "C4", "Cell feature": "expression_mg", "Test AP": 0.87, "Test gene AP": 0.89, "Test cell AP": 0.85},
]

df = pd.DataFrame(data)

# %% [markdown]
# # 2. Plots

# %%
df.groupby("Model")[["Test AP", "Test gene AP", "Test cell AP"]].mean().plot.bar(rot=0)
# Out:
# <Axes: xlabel='Model'>

# %%
import seaborn as sns
sns.catplot(
    data=df, kind="bar",
    x="Cell feature", y="Test AP",
    hue="Model", col="Gene feature",
    height=4, aspect=1
)

# %%
sns.boxplot(data=df, x="Model", y="Test AP")
# Out:
# <Axes: xlabel='Model', ylabel='Test AP'>

# %% [markdown]
# ### AP scores by model

# %% [markdown]
# #### scatter plots

# %%
# Map gene features to colors
palette = {"CGP": "red", "C4": "black"}

# Plot
plt.figure(figsize=(9, 6))
sns.stripplot(data=df, x="Model", y="Test AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.stripplot(data=df, x="Model", y="Test gene AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test gene AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.stripplot(data=df, x="Model", y="Test cell AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test cell AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### boxplots

# %%
# Map gene features to colors
palette = {"CGP": "red", "C4": "black"}

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Model", y="Test AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Model", y="Test AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Model", y="Test gene AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Model", y="Test gene AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test gene AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Model", y="Test cell AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Model", y="Test cell AP", hue="Gene feature", palette=palette, jitter=True, size=6)

plt.title("Test cell AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### AP scores by cell feature

# %% [markdown]
# #### colored by gene feature

# %%
# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test AP", hue="Gene feature", palette=palette, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()


# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test cell AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test cell AP", hue="Gene feature", palette=palette, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test cell AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()


# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test gene AP", hue="Gene feature", palette=palette, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test gene AP", hue="Gene feature", palette=palette, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test gene AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### colored by model

# %%
palette2 = {"GNN": "red", "GNN-GNN": "black", "MLP-GNN": "blue", "MLP": "green"}

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test AP", hue="Model", palette=palette2, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test AP", hue="Model", palette=palette2, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test cell AP", hue="Model", palette=palette2, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test cell AP", hue="Model", palette=palette2, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test cell AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# Plot
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x="Cell feature", y="Test gene AP", hue="Model", palette=palette2, dodge=True, fliersize=0)
sns.stripplot(data=df, x="Cell feature", y="Test gene AP", hue="Model", palette=palette2, dodge=True, jitter=True, size=4, alpha=0.6)

plt.title("Test gene AP by Model Colored by Gene Feature")
plt.ylim(0.85, 0.95)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Gene Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Statisctical tests

# %% [markdown]
# ## For model

# %%
from scipy.stats import f_oneway

# Example: Test AP by model
groups = [df[df["Model"] == model]["Test AP"] for model in df["Model"].unique()]
f_stat, p_val = f_oneway(*groups)
print("ANOVA Test AP by Model: p =", p_val)
# Out:
# ANOVA Test AP by Model: p = 0.06807490059045254

# %% [markdown]
# Null hypothesis: all model's test AP are equal
# --> cannot be rejected because p = 0,14 > 0,05

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=df["Test AP"], groups=df["Model"], alpha=0.05)
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj   lower  upper  reject
# -----------------------------------------------------
#     GNN GNN-GNN     0.01 0.5069 -0.0094 0.0294  False
#     GNN     MLP   0.0038 0.9519 -0.0157 0.0232  False
#     GNN MLP-GNN   0.0187 0.0616 -0.0007 0.0382  False
# GNN-GNN     MLP  -0.0062 0.8161 -0.0257 0.0132  False
# GNN-GNN MLP-GNN   0.0087  0.614 -0.0107 0.0282  False
#     MLP MLP-GNN    0.015 0.1755 -0.0044 0.0344  False
# -----------------------------------------------------

# %% [markdown]
# Conclusion: all models score equally well

# %% [markdown]
# ## For gene feature

# %%
tukey = pairwise_tukeyhsd(endog=df["Test AP"], groups=df["Gene feature"], alpha=0.05)
print(tukey)

groups = [df[df["Gene feature"] == feature]["Test AP"] for feature in df["Gene feature"].unique()]
f_stat, p_val = f_oneway(*groups)
print("ANOVA Test AP by Gene Feature: p =", p_val)

df.groupby("Gene feature")["Test AP"].mean()
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     C4    CGP    0.015 0.0038 0.0052 0.0248   True
# --------------------------------------------------
# ANOVA Test AP by Gene Feature: p = 0.0038076558955251927
# Gene feature
# C4     0.904375
# CGP    0.919375
# Name: Test AP, dtype: float64

# %% [markdown]
# Conclusion: p<0.05. This means that the CGP scores significantly better than the C4 ?

# %%
tukey = pairwise_tukeyhsd(endog=df["Test gene AP"], groups=df["Gene feature"], alpha=0.05)
print(tukey)

groups = [df[df["Gene feature"] == feature]["Test gene AP"] for feature in df["Gene feature"].unique()]
f_stat, p_val = f_oneway(*groups)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     C4    CGP   0.0044 0.4785 -0.0081 0.0168  False
# ---------------------------------------------------

# %%
tukey = pairwise_tukeyhsd(endog=df["Test cell AP"], groups=df["Gene feature"], alpha=0.05)
print(tukey)

groups = [df[df["Gene feature"] == feature]["Test cell AP"] for feature in df["Gene feature"].unique()]
f_stat, p_val = f_oneway(*groups)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     C4    CGP   0.0175 0.002 0.0069 0.0281   True
# -------------------------------------------------

# %%
df.groupby("Gene feature")["Test cell AP"].mean()
# Out:
# Gene feature
# C4     0.878125
# CGP    0.895625
# Name: Test cell AP, dtype: float64

# %% [markdown]
# ## For cell features

# %%
tukey = pairwise_tukeyhsd(endog=df["Test gene AP"], groups=df["Cell feature"], alpha=0.05)
print(tukey)

df.groupby("Cell feature")["Test gene AP"].mean()
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1       group2    meandiff p-adj   lower  upper  reject
# --------------------------------------------------------------
#        CNV          MOSA   0.0337    0.0  0.0178 0.0497   True
#        CNV    expression   0.0262 0.0006  0.0103 0.0422   True
#        CNV expression_mg   0.0262 0.0006  0.0103 0.0422   True
#       MOSA    expression  -0.0075 0.5795 -0.0234 0.0084  False
#       MOSA expression_mg  -0.0075 0.5795 -0.0234 0.0084  False
# expression expression_mg      0.0    1.0 -0.0159 0.0159  False
# --------------------------------------------------------------
# Cell feature
# CNV              0.87750
# MOSA             0.91125
# expression       0.90375
# expression_mg    0.90375
# Name: Test gene AP, dtype: float64

# %%
tukey = pairwise_tukeyhsd(endog=df["Test AP"], groups=df["Cell feature"], alpha=0.05)
print(tukey)

df.groupby("Cell feature")["Test AP"].mean()
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1       group2    meandiff p-adj   lower  upper  reject
# --------------------------------------------------------------
#        CNV          MOSA   0.0013 0.9986 -0.0207 0.0232  False
#        CNV    expression   0.0025 0.9893 -0.0194 0.0244  False
#        CNV expression_mg  -0.0012 0.9986 -0.0232 0.0207  False
#       MOSA    expression   0.0012 0.9986 -0.0207 0.0232  False
#       MOSA expression_mg  -0.0025 0.9893 -0.0244 0.0194  False
# expression expression_mg  -0.0038 0.9657 -0.0257 0.0182  False
# --------------------------------------------------------------
# Cell feature
# CNV              0.91125
# MOSA             0.91250
# expression       0.91375
# expression_mg    0.91000
# Name: Test AP, dtype: float64

# %%
tukey = pairwise_tukeyhsd(endog=df["Test cell AP"], groups=df["Cell feature"], alpha=0.05)
print(tukey)

df.groupby("Cell feature")["Test cell AP"].mean()
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1       group2    meandiff p-adj   lower  upper  reject
# --------------------------------------------------------------
#        CNV          MOSA    0.005 0.9407  -0.019  0.029  False
#        CNV    expression   0.0038 0.9735 -0.0203 0.0278  False
#        CNV expression_mg  -0.0012  0.999 -0.0253 0.0228  False
#       MOSA    expression  -0.0013  0.999 -0.0253 0.0228  False
#       MOSA expression_mg  -0.0063 0.8922 -0.0303 0.0178  False
# expression expression_mg   -0.005 0.9407  -0.029  0.019  False
# --------------------------------------------------------------
# Cell feature
# CNV              0.88500
# MOSA             0.89000
# expression       0.88875
# expression_mg    0.88375
# Name: Test cell AP, dtype: float64
